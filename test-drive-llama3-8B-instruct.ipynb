# %% [markdown]
# #### Uses the instruct model for chat use-case

# %%
# !mkdir llama3-demo
# %cd llama3-demo 
# !git clone https://github.com/meta-llama/llama3.git
# Out:
# mkdir: cannot create directory ‘llama3-demo’: File exists
# /llama3-demo
# fatal: destination path 'llama3' already exists and is not an empty directory.
# /opt/vast-jupyter/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd llama3
# !pip install -e .
# Out:
# /llama3-demo/llama3
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Obtaining file:///llama3-demo/llama3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llama3 (pyproject.toml) ... done
#   Created wheel for llama3: filename=llama3-0.0.1-0.editable-py3-none-any.whl size=7706 sha256=f8ee70e04477cdf51713e572483f6553b98556cbbe9de911f1b2338ebe7c8da8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jqgr7p85/wheels/97/19/57/7dc6689a41b922843ea6e834068a5bdf68b49af3906eb21ebd
# Successfully built llama3
# ...
#   Attempting uninstall: llama3
#     Found existing installation: llama3 0.0.1
#     Uninstalling llama3-0.0.1:
#       Successfully uninstalled llama3-0.0.1
# ...

# %%
# !pip install llama-stack
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# !llama model list
# Out:
# +----------------------------------+------------------------------------------+----------------+
# | Model Descriptor                 | Hugging Face Repo                        | Context Length |
# +----------------------------------+------------------------------------------+----------------+
# | Llama3.1-8B                      | meta-llama/Llama-3.1-8B                  | 128K           |
# +----------------------------------+------------------------------------------+----------------+
# | Llama3.1-70B                     | meta-llama/Llama-3.1-70B                 | 128K           |
# +----------------------------------+------------------------------------------+----------------+
# | Llama3.1-405B:bf16-mp8           | meta-llama/Llama-3.1-405B                | 128K           |
# +----------------------------------+------------------------------------------+----------------+
# | Llama3.1-405B                    | meta-llama/Llama-3.1-405B-FP8            | 128K           |
# ...

# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
# go here for token: https://huggingface.co/settings/tokens
from huggingface_hub import notebook_login
notebook_login()

# %%
# !huggingface-cli download meta-llama/Meta-Llama-3.1-8B --include "original/*" --local-dir meta-llama/Meta-Llama-3.1-8B
# Out:
# Fetching 3 files:   0%|                                   | 0/3 [00:00<?, ?it/s]Downloading 'original/tokenizer.model' to 'meta-llama/Meta-Llama-3.1-8B/.cache/huggingface/download/original/tokenizer.model.82e9d31979e92ab929cd544440f129d9ecd797b69e327f80f17e1c50d5551b55.incomplete'
# ...
#
# original/params.json: 100%|████████████████████| 199/199 [00:00<00:00, 1.28MB/s]
# Download complete. Moving file to meta-llama/Meta-Llama-3.1-8B/original/params.json
#
# tokenizer.model:   0%|                              | 0.00/2.18M [00:00<?, ?B/s]Downloading 'original/consolidated.00.pth' to 'meta-llama/Meta-Llama-3.1-8B/.cache/huggingface/download/original/consolidated.00.pth.a4bf93805847a87006dfc036ec518dc1ff94605f3a0bcd819916477ae9dcafbc.incomplete'
# tokenizer.model: 100%|█████████████████████| 2.18M/2.18M [00:00<00:00, 70.8MB/s]
# Download complete. Moving file to meta-llama/Meta-Llama-3.1-8B/original/tokenizer.model
#
# ...

# %%
# !ls -l meta-llama/Meta-Llama-3.1-8B-Instruct/original
# Out:
# total 15686340
# -rw-r--r-- 1 root root 16060617592 Oct  3 06:27 consolidated.00.pth
# -rw-r--r-- 1 root root         199 Oct  3 06:26 params.json
# -rw-r--r-- 1 root root     2183982 Oct  3 06:26 tokenizer.model

# %%
# !torchrun --nproc_per_node 1 example_text_completion.py --ckpt_dir meta-llama/Meta-Llama-3.1-8B/original/ --tokenizer_path meta-llama/Meta-Llama-3.1-8B/original/tokenizer.model --max_seq_len 128 --max_batch_size 4
# Out:
# > initializing model parallel with size 1
# > initializing ddp with size 1
# > initializing pipeline with size 1
# ...

# %%
# !pwd
# Out:
# /llama3-demo/llama3

# %%
# cd /llama3-demo/llama3/meta-llama/Meta-Llama-3.1-8B-Instruct/ and fix params.json
